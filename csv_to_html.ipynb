# %%
import pandas as pd
from IPython.display import HTML
import pprint

# %%
data_df = pd.read_csv('Resources\weather_data.csv')
data_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        Urrao          20      CO  1578442303        53   6.32  -76.13
# 1      Qaanaaq          15      GL  1578442303        81  77.48  -69.36
# 2  Tuktoyaktuk          40      CA  1578442304        66  69.44 -133.03
# 3     Bilibino           0      RU  1578442304        90  68.06  166.44
# 4       Torbay          90      CA  1578442304        79  47.66  -52.73
#
#    Max Temp  Wind Speed
# 0     75.20       16.11
# 1    -25.51        1.07
# 2    -32.80       11.41
# 3    -27.85        3.00
# 4     24.01        5.82

# %%
html_code = data_df.to_html(classes='table table-striped')
html_code
# Out:
# '<table border="1" class="dataframe table table-striped">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Humidity</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Urrao</td>\n      <td>20</td>\n      <td>CO</td>\n      <td>1578442303</td>\n      <td>53</td>\n      <td>6.32</td>\n      <td>-76.13</td>\n      <td>75.20</td>\n      <td>16.11</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Qaanaaq</td>\n      <td>15</td>\n      <td>GL</td>\n      <td>1578442303</td>\n      <td>81</td>\n      <td>77.48</td>\n      <td>-69.36</td>\n      <td>-25.51</td>\n      <td>1.07</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Tuktoyaktuk</td>\n      <td>40</td>\n      <td>CA</td>\n      <td>1578442304</td>\n      <td>66</td>\n      <td>69.44</td>\
# ...

# %%
data_df.to_html('Resources\weather_html.html')
